# %% [markdown]
# # podstawowy

# %%
print("to jest test notebooka!")
r = 12
print(r)
# Out:
# to jest test notebooka!
# 12

# %%
c = 4*r + 1
print(c)
# Out:
# 49

# %% [markdown]
# # Pierwsze użycie <span style="color:red; font-size:28pt;">Jupyter</span> **Notebook**!

# %% [markdown]
# $$ Tensor \;  \mathcal{X} \in \mathbb{R}^{S \times T \times F}  $$

# %% [markdown]
# Podaj liczbę sztuk produktu:

# %%
lsztuk = 6

# %%
cena = "3.77"

# %%
f"do zapłaty: {lsztuk*float(cena):.2f} zł"
# Out:
# 'do zapłaty: 22.62 zł'

# %%
rabat = 0.12*float(cena)

# %% [markdown]
# # dodatkowy

# %%
rabat
# Out:
# 0.45239999999999997
